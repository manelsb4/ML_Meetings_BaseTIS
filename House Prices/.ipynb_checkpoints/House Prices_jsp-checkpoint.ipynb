# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
plt.style.use('ggplot')
import missingno as msno

plt.style.use('fivethirtyeight')
sns.set_palette("GnBu_d")

# %%
path = 'C:/Users/joan.soler/Documents/GitHub/ML_Meetings_BaseTIS/House Prices/data/'

# Cargamos los dos sets de datos en dos Dataframes de Pandas.
test = pd.read_csv(path + 'test.csv', sep = ',')
train = pd.read_csv(path + 'train.csv', sep = ',')

# %%
test_c = set(test.columns)
train_c = set(train.columns)
target = train_c -test_c
target
# Out:
# {'SalePrice'}

# %%
#(1460, 81)
train.head()
#train.shape
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#MSSubClass    1   --DISC
#Street        1   --DISC
#MSZoning      0   --DISC
                    #lotArea       2   --CONT
                        #Alley     -2  --DIST mes informativa que STREET? MOLTS NULLS
#LotShape      1   --DISC
#YearBuilt     1
#Utilities     1
#Exterior1st   1
#Heating       1
#PoolQC        1

# %%
msno.matrix(train[['OverallQual']])

# %%
#Generem la taula de correlacions per agafar els camps amb mes correlació amb el Preu
train_corr = abs(train.corr())
train_corr = train_corr.sort_values('SalePrice',ascending=False)
Ntrain = train[train_corr.loc[train_corr['SalePrice'] > 0.4].index]
#Ntrain = train[train_corr.columns]
#train_corr = train_corr.sort_values('SalePrice',ascending=False))
#train_corr['SalePrice']
#plt.figure(figsize=(6,6))
#s = sns.heatmap(train.corr(), annot=True, fmt = ".2f", cmap="YlGnBu")
#sns.factorplot(x='',y='SalePrice', data=train, kind='bar', size=6)

# %%
Ntrain.columns
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt',
#        'YearRemodAdd', 'GarageYrBlt', 'MasVnrArea', 'Fireplaces'],
#       dtype='object')

# %%
Ntrain.isnull().sum()
Ntrain.columns[Ntrain.isnull().any()]
# Out:
# Index(['GarageYrBlt', 'MasVnrArea'], dtype='object')

# %%
msno.matrix(Ntrain)

# %%
#MasVnrArea         8
#GarageYrBlt       81

s = sns.distplot(Ntrain.loc[Ntrain['MasVnrArea'].notnull(),'MasVnrArea'])
Ntrain.loc[Ntrain['MasVnrArea'].isnull(),'MasVnrArea'] = 0
#s = sns.distplot(Ntrain['MasVnrArea'])
#log_Area = Ntrain['MasVnrArea'].map(lambda x: np.log(x) if x > 0 else 0)
#log_Area
#s = sns.distplot(log_Area.loc[log_Area['MasVnrArea'].notnull(),'MasVnrArea'])

# %%
#sns.distplot(Ntrain.loc[Ntrain['GarageYrBlt'].notnull(),'GarageYrBlt'])
#Ntrain[['GarageYrBlt','YearBuilt']]
Year = Ntrain.loc[Ntrain['GarageYrBlt'].notnull(),['GarageYrBlt','YearBuilt']]
Year['diff'] = Year['GarageYrBlt'] - Year['YearBuilt']
Year
#Year.groupby(['diff']).count()
#sns.distplot(Year['diff'])
#tractament de nulls
Ntrain.loc[Ntrain['GarageYrBlt'].isnull(),'GarageYrBlt'] = Ntrain.loc[Ntrain['GarageYrBlt'].isnull(),'YearBuilt']
#No te sentit que el Garatge es contrueixi abans que la casa
Ntrain.loc[Ntrain['GarageYrBlt'] - Ntrain['YearBuilt']< 0,'GarageYrBlt'] = Ntrain.loc[Ntrain['GarageYrBlt'] - Ntrain['YearBuilt']< 0,'YearBuilt']
sns.distplot(Ntrain.loc[Ntrain['GarageYrBlt'].notnull(),'GarageYrBlt'])

# %%
Ntrain
#s = sns.factorplot(x="OverallQual", y="SalePrice", data=Ntrain, size=6, kind="bar", palette="GnBu_d")
#s = plt.scatter(x ='GrLivArea', y ='SalePrice', data=Ntrain)
#s = sns.factorplot(x="GarageCars", y="SalePrice", data=Ntrain, size=6, kind="bar", palette="GnBu_d")
s = plt.scatter(x ='GarageArea', y ='SalePrice', data=Ntrain)
